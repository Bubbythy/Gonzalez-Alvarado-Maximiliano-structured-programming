# %% [markdown]
# <a href="https://colab.research.google.com/github/Bubbythy/Gonzalez-Alvarado-Maximiliano-structured-programming/blob/main/LAB_4_Gonzalez_Alvarado_Maximiliano.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# lab 4 institutional email generator
# students will create a function that automatically generates an institutional email address from a person's first name and lastname

# variable declarations
condition="yes"



def generate_email(name, lastname):
    email = f"{name.lower()}.{lastname.lower()}@utd.edu.mx"
    return email

while condition.lower()== "yes":
    name = input("Dame tu nombre: ")
    lastname = input("Dame tu apellido: ")

    email= generate_email(name, lastname)
    print("Your institutional email is: ", email)

    condition= input("Quieres generar otro correo? (SI/NO)" )
# Out:
# Dame tu nombre: maximiliano
# Dame tu apellido: gonzalez
# Your institutional email is:  maximiliano.gonzalez@utd.edu.mx
# Quieres generar otro correo? (SI/NO)no

# %%
# Detrermine scholarship


def evaluar_beca(promedio, ingreso):
    if promedio >= 9.0:
        return "Beca aprobada por Excelencia."
    elif promedio >= 8.0 and ingreso <= 6000:
        return "Beca aprobada por Apoyo Social."
    else:
        return "Beca rechazada."


while True:
    print("Validador de Becas")

    nombre = input("Nombre del alumno: ")
    promedio = float(input("Promedio: "))
    ingreso = float(input("Ingreso mensual: "))

    resultado = evaluar_beca(promedio, ingreso)
    print(f"Estado de {nombre}: {resultado}")

    continuar = input("¿Quieres checar otro? (s/n): ").lower()
    if continuar != "s":
        break
# Out:
# Validador de Becas
# Nombre del alumno: maximiliano
# Promedio: 9.2
# Ingreso mensual: 500
# Estado de maximiliano: Beca aprobada por Excelencia.
# ¿Quieres checar otro? (s/n): no
